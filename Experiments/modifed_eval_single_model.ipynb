# %%
# !git clone https://github.com/ryuan19/focal_calibration_project
# Out:
# Cloning into 'focal_calibration_project'...
# remote: Enumerating objects: 363, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 363 (delta 21), reused 17 (delta 7), pack-reused 320
# Receiving objects: 100% (363/363), 1.60 MiB | 29.32 MiB/s, done.
# Resolving deltas: 100% (152/152), done.

# %%
# !rm -rf focal_calibration_project

# %%
# !python focal_calibration_project/train.py --dataset cifar10 --model resnet50 --loss iq_loss --gamma 3.0
# Out:
# CUDA set: True
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified
# ...

# %%
# !zip -r /content/focal_calibration_project.zip /content/focal_calibration_project
# Out:
# updating: content/focal_calibration_project/ (stored 0%)
# updating: content/focal_calibration_project/LICENSE (deflated 41%)
# updating: content/focal_calibration_project/__pycache__/ (stored 0%)
# updating: content/focal_calibration_project/__pycache__/train_utils.cpython-37.pyc (deflated 41%)
# updating: content/focal_calibration_project/README.md (deflated 60%)
# updating: content/focal_calibration_project/resnet50_results.png (deflated 20%)
# updating: content/focal_calibration_project/evaluate.py (deflated 73%)
# updating: content/focal_calibration_project/appspec.yml (deflated 55%)
# updating: content/focal_calibration_project/Metrics/ (stored 0%)
# updating: content/focal_calibration_project/Metrics/ood_test_utils.py (deflated 77%)
# updating: content/focal_calibration_project/Metrics/__pycache__/ (stored 0%)
# updating: content/focal_calibration_project/Metrics/__pycache__/__init__.cpython-37.pyc (deflated 22%)
# ...

# %%
# !python focal_calibration_project/evaluate.py --dataset cifar10 --model resnet50 --save-path focal_calibration_project/models/ --saved_model_name resnet50_iq_loss_alpha_1.0_best_9.model --cverror ece
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...
